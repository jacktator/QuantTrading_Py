# %%
# Fetching Industry

Fetching historical data for industry which **AXP** (American Express) belongs to.

# %%
from abupy import ABuIndustries

symbol = 'usAXP'

downloaded_panel, _ = ABuIndustries.get_industries_panel_from_target(symbol,
                                                           show=True)
# Out:
# Box(children=(Text(value='pid=63879 begin work'), FloatProgress(value=0.0)))

# %% [markdown]
# # Panel Info

# %%
downloaded_panel.axes
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-20-74a5442bdb61> in <module>
#       1
# ----> 2 downloaded_panel.head()
#       3
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/panel.py in head(self, n)
#     657
#     658     def head(self, n=5):
# --> 659         raise NotImplementedError
#     660
#     661     def tail(self, n=5):
#
# NotImplementedError:

# %% [markdown]
# # Saving Panel
#
# TODO: Saving panel data as a local `.csv` file.

# %%
downloaded_panel.to_csv('../gen/fin_svs_p.csv')

# %% [markdown]
# # Reading Panel
#
# TODO: Reading panel data from local `.csv` file.

# %%
import pandas as pd

local_df = pd.read_csv('../gen/fin_svs_p.csv',
                           parse_dates=True,
                           index_col=0)

local_df.head()
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Data Info
#
# TODO:

# %%
local_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4704 entries, 2017-06-12 to 2018-12-31
# Data columns (total 5 columns):
# minor    4704 non-null object
# usMCO    4704 non-null float64
# usMA     4704 non-null float64
# usV      4704 non-null float64
# usAXP    4704 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 220.5+ KB

# %% [markdown]
# # Data Description
#
# TODO:

# %%
local_df.describe()
# Out:
#             usMCO        usMA         usV       usAXP
# count  4.7040e+03  4.7040e+03  4.7040e+03  4.7040e+03
# mean   1.7473e+06  1.9699e+06  2.3102e+06  1.9542e+06
# std    5.5635e+06  5.5946e+06  5.8816e+06  5.5899e+06
# min   -8.6380e+00 -6.2310e+00 -4.8390e+00 -5.6300e+00
# 25%    3.3843e+00  4.0000e+00  2.9178e+00  2.3706e+00
# 50%    1.4613e+02  1.5126e+02  1.1328e+02  9.4340e+01
# 75%    1.7616e+02  2.0698e+02  1.4409e+02  1.0835e+02
# max    2.0181e+07  2.0181e+07  2.5449e+07  2.0181e+07
